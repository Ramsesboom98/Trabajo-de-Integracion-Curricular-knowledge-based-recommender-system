# %%
import sqlite3
import xml.etree.ElementTree as ET
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import csv
import math as mt

# %% [markdown]
# INTERSECCIONES

# %%
intersections_matrix = np.zeros((952,952))

# %%
cell_rad_df = pd.read_csv('../datos/cell_c_radii_df.csv',index_col=0)
cell_rad_df
# Out:
#      cell_name                                             center        r2
# 0    CVCL_2260  [0.13507872568263754, 0.0077602583237698875, -...  0.375213
# 1    CVCL_4806  [0.1438778206697353, 0.04852056233703366, 0.00...  0.596738
# 2    CVCL_M605  [0.16614108207377254, -0.03146658964662872, -0...  0.461877
# 3    CVCL_0464  [0.14870812739929176, -0.03909651168168045, -0...  0.389280
# 4    CVCL_8987  [0.14744802491027653, -0.006443613530958713, 0...  0.390232
# ..         ...                                                ...       ...
# 947  CVCL_A637  [0.1829866677575736, 0.12900832884666108, -0.0...  0.646020
# 948  CVCL_2992  [0.20110780215403065, 0.19934965910049354, -0....  0.760930
# 949  CVCL_2995  [0.17920858897094452, 0.07658716285881599, -0....  0.474875
# 950  CVCL_A446  [0.18076409674022065, 0.01428818391511522, -0....  0.500937
# 951  CVCL_2998  [0.17767530608002566, 0.009062908152727051, -0...  0.489679
#
# [952 rows x 3 columns]

# %%
def distancia(punto_a,punto_b):
    
    resta = list(map(lambda x,y: x-y ,punto_a,punto_b))
    vector = np.array(resta) 
    return mt.sqrt(sum(pow(element, 2) for element in vector))

# %%
for cell_a in cell_rad_df.iterrows():
    cell_a_centroid =  eval(cell_a[1][1])
    cell_r1 = cell_a[1][2]
    print(cell_a[1][0])
    for cell_b in cell_rad_df.iterrows():
        if cell_a[0]!=cell_b[0]:
            cell_b_centroid =  eval(cell_b[1][1])
            cell_r2 = cell_b[1][2]
            dist_cell =distancia(cell_a_centroid,cell_b_centroid)
            radios =cell_r1 + cell_r2 
            intersec = (radios - dist_cell) / radios
            intersections_matrix[cell_a[0]][cell_b[0]] =intersec
        else:
            intersections_matrix[cell_a[0]][cell_b[0]] = 0

# %%
df_inter = pd.read_csv('intersecciones_div_rad.csv',index_col=0)
df_inter
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.000000  0.622633  0.680323  0.573238  0.605027  0.647219  0.476542
# 1    0.622633  0.000000  0.686786  0.623624  0.662028  0.685622  0.573397
# 2    0.680323  0.686786  0.000000  0.734585  0.751432  0.804586  0.641205
# 3    0.573238  0.623624  0.734585  0.000000  0.668115  0.706848  0.517472
# 4    0.605027  0.662028  0.751432  0.668115  0.000000  0.883225  0.559432
# ..        ...       ...       ...       ...       ...       ...       ...
# 947  0.611179  0.660811  0.687087  0.623670  0.650260  0.673821  0.589297
# 948  0.646068  0.693528  0.714912  0.658378  0.682992  0.701777  0.638032
# 949  0.458724  0.541455  0.562520  0.481329  0.501897  0.531238  0.423159
# 950  0.501885  0.575737  0.597221  0.519176  0.539655  0.571933  0.460608
# 951  0.612686  0.672090  0.717124  0.625522  0.675172  0.701592  0.572779
#
#             7         8         9  ...       942       943       944  \
# 0    0.540673  0.725521  0.694860  ...  0.679157  0.606243  0.703313
# 1    0.594517  0.738885  0.718517  ...  0.712606  0.663454  0.734318
# 2    0.746098  0.847227  0.800672  ...  0.748312  0.682017  0.775222
# 3    0.603350  0.837212  0.726183  ...  0.687896  0.622809  0.719502
# 4    0.670134  0.803410  0.759298  ...  0.716251  0.658117  0.746114
# ..        ...       ...       ...  ...       ...       ...       ...
# 947  0.608352  0.743673  0.725971  ...  0.894764  0.679563  0.908980
# 948  0.644301  0.767567  0.752007  ...  0.866035  0.719262  0.889573
# 949  0.407056  0.634729  0.623862  ...  0.769969  0.551141  0.776267
# 950  0.459712  0.659645  0.642386  ...  0.790619  0.583985  0.777815
# 951  0.617883  0.753910  0.740106  ...  0.729905  0.653840  0.738727
#
#           945       946       947       948       949       950       951
# 0    0.709013  0.662246  0.611179  0.646068  0.458724  0.501885  0.612686
# 1    0.740103  0.701452  0.660811  0.693528  0.541455  0.575737  0.672090
# 2    0.776566  0.732743  0.687087  0.714912  0.562520  0.597221  0.717124
# 3    0.721479  0.672385  0.623670  0.658378  0.481329  0.519176  0.625522
# 4    0.751295  0.698051  0.650260  0.682992  0.501897  0.539655  0.675172
# ..        ...       ...       ...       ...       ...       ...       ...
# 947  0.898402  0.847116  0.000000  0.861852  0.732408  0.727008  0.653100
# 948  0.881599  0.817999  0.861852  0.000000  0.751129  0.687324  0.684481
# 949  0.770896  0.761824  0.732408  0.751129  0.000000  0.576020  0.523159
# 950  0.799448  0.814443  0.727008  0.687324  0.576020  0.000000  0.603742
# 951  0.746370  0.711623  0.653100  0.684481  0.523159  0.603742  0.000000
#
# [952 rows x 952 columns]

# %%
#calculo mayor valor
maximo_val = df_inter.max() #encuentra el maximo de cada columna, en este caso las columnas son las celulas
maximos =maximo_val.to_frame()
maximos.nlargest(1,0)
# Out:
#             0
# 137  0.989414

# %%
minimo_val = df_inter.min()
minimos =minimo_val.to_frame()
minimos.nsmallest(1,0)
# Out:
#             0
# 771 -1.763669

# %%
nombres= cell_rad_df['cell_name']
df_inter_cell = pd.concat([nombres, df_inter], axis=1)
df_inter_cell
# Out:
#      cell_name         0         1         2         3         4         5  \
# 0    CVCL_2260  0.000000  0.622633  0.680323  0.573238  0.605027  0.647219
# 1    CVCL_4806  0.622633  0.000000  0.686786  0.623624  0.662028  0.685622
# 2    CVCL_M605  0.680323  0.686786  0.000000  0.734585  0.751432  0.804586
# 3    CVCL_0464  0.573238  0.623624  0.734585  0.000000  0.668115  0.706848
# 4    CVCL_8987  0.605027  0.662028  0.751432  0.668115  0.000000  0.883225
# ..         ...       ...       ...       ...       ...       ...       ...
# 947  CVCL_A637  0.611179  0.660811  0.687087  0.623670  0.650260  0.673821
# 948  CVCL_2992  0.646068  0.693528  0.714912  0.658378  0.682992  0.701777
# 949  CVCL_2995  0.458724  0.541455  0.562520  0.481329  0.501897  0.531238
# 950  CVCL_A446  0.501885  0.575737  0.597221  0.519176  0.539655  0.571933
# 951  CVCL_2998  0.612686  0.672090  0.717124  0.625522  0.675172  0.701592
#
#             6         7         8  ...       942       943       944  \
# 0    0.476542  0.540673  0.725521  ...  0.679157  0.606243  0.703313
# 1    0.573397  0.594517  0.738885  ...  0.712606  0.663454  0.734318
# 2    0.641205  0.746098  0.847227  ...  0.748312  0.682017  0.775222
# 3    0.517472  0.603350  0.837212  ...  0.687896  0.622809  0.719502
# 4    0.559432  0.670134  0.803410  ...  0.716251  0.658117  0.746114
# ..        ...       ...       ...  ...       ...       ...       ...
# 947  0.589297  0.608352  0.743673  ...  0.894764  0.679563  0.908980
# 948  0.638032  0.644301  0.767567  ...  0.866035  0.719262  0.889573
# 949  0.423159  0.407056  0.634729  ...  0.769969  0.551141  0.776267
# 950  0.460608  0.459712  0.659645  ...  0.790619  0.583985  0.777815
# 951  0.572779  0.617883  0.753910  ...  0.729905  0.653840  0.738727
#
#           945       946       947       948       949       950       951
# 0    0.709013  0.662246  0.611179  0.646068  0.458724  0.501885  0.612686
# 1    0.740103  0.701452  0.660811  0.693528  0.541455  0.575737  0.672090
# 2    0.776566  0.732743  0.687087  0.714912  0.562520  0.597221  0.717124
# 3    0.721479  0.672385  0.623670  0.658378  0.481329  0.519176  0.625522
# 4    0.751295  0.698051  0.650260  0.682992  0.501897  0.539655  0.675172
# ..        ...       ...       ...       ...       ...       ...       ...
# 947  0.898402  0.847116  0.000000  0.861852  0.732408  0.727008  0.653100
# 948  0.881599  0.817999  0.861852  0.000000  0.751129  0.687324  0.684481
# 949  0.770896  0.761824  0.732408  0.751129  0.000000  0.576020  0.523159
# 950  0.799448  0.814443  0.727008  0.687324  0.576020  0.000000  0.603742
# 951  0.746370  0.711623  0.653100  0.684481  0.523159  0.603742  0.000000
#
# [952 rows x 953 columns]

# %%
df_mapeo_cell = pd.read_csv('../datos/cell_mapping.csv',index_col=0)
df_mapeo_cell
# Out:
#                cell_description  cell_id  cell_name cell_source_organism  \
# cell_chembl_id
# CHEMBL3307241              DC3F        1       DC3F   Cricetulus griseus
# CHEMBL3307242            P3HR-1        2     P3HR-1         Homo sapiens
# CHEMBL3307243          UCLA P-3        3   UCLA P-3         Homo sapiens
# CHEMBL3307244          UMSCC22B        4   UMSCC22B         Homo sapiens
# CHEMBL3307245             UMUC3        5      UMUC3         Homo sapiens
# ...                         ...      ...        ...                  ...
# CHEMBL3308306         KNS-81-FD     1696  KNS-81-FD         Homo sapiens
# CHEMBL3308307         KURAMOCHI     1697  KURAMOCHI         Homo sapiens
# CHEMBL3308308         LB771-HNC     1698  LB771-HNC         Homo sapiens
# CHEMBL3308853         LB831-BLC     1699  LB831-BLC         Homo sapiens
# CHEMBL3308309         LB996-RCC     1700  LB996-RCC         Homo sapiens
#
#                 cell_source_tax_id   cell_source_tissue cellosaurus_id  \
# cell_chembl_id
# CHEMBL3307241              10029.0                 Lung      CVCL_4704
# CHEMBL3307242               9606.0              Lyphoma      CVCL_2676
# CHEMBL3307243               9606.0  Lung Adenocarcinoma      CVCL_N513
# CHEMBL3307244               9606.0            Carcinoma      CVCL_7732
# CHEMBL3307245               9606.0    Bladder Carcinoma      CVCL_1783
# ...                            ...                  ...            ...
# CHEMBL3308306               9606.0                  NaN      CVCL_1336
# CHEMBL3308307               9606.0                  NaN      CVCL_1345
# CHEMBL3308308               9606.0                  NaN      CVCL_1369
# CHEMBL3308853               9606.0                  NaN      CVCL_1370
# CHEMBL3308309               9606.0                  NaN      CVCL_1371
#
#                cl_lincs_id       clo_id       efo_id
# cell_chembl_id
# CHEMBL3307241          NaN          NaN          NaN
# CHEMBL3307242     LCL-2024  CLO_0008331  EFO_0002312
# CHEMBL3307243          NaN          NaN          NaN
# CHEMBL3307244          NaN          NaN          NaN
# CHEMBL3307245     LCL-1721  CLO_0009487  EFO_0002387
# ...                    ...          ...          ...
# CHEMBL3308306     LCL-1383          NaN          NaN
# CHEMBL3308307     LCL-1701          NaN          NaN
# CHEMBL3308308     LCL-1575          NaN          NaN
# CHEMBL3308853     LCL-1707          NaN          NaN
# CHEMBL3308309     LCL-1767          NaN          NaN
#
# [1554 rows x 10 columns]

# %%
#top 10 con mapeo a cell_id

lista= []

#Se recorre el dataframe  horizontalmente
for label,content  in df_inter_cell.items():
    if label != 'cell_name':
        
        
        id = int(label)
        #Obtenemos el nombre de la linea celular actual con la ayuda del label recorrido
        name = df_inter_cell['cell_name'][id]

        #Otenemos el top 10
        top10 = df_inter_cell.nlargest(10,str(id))[['cell_name',str(id)]]

        #Guardamos en una lista los nombres de su top3 
        lista_top10 = top10['cell_name'].tolist()
        

        #Realizamos un cutoff para los valores mayyores a 0.8 

        lista_val_top10 = [val for val in top10[label].tolist() if val >= 0.8]

        lista_top10= lista_top10[:len(lista_val_top10)]

       
       #Si ninguna linea celular del top10 supero el cutoff no se la añade 

        if len(lista_top10) !=0:
            #----------------------------------------

            #Realizamos el mapeo 

            df_name_map = df_mapeo_cell[df_mapeo_cell['cellosaurus_id'].isin([name])]

            #si encuentra que existe la celula actual en el mapeo entonces se lo agrega
            if  not df_name_map.empty:
                
                cells =[]
                values=[]                
                
                for index,cell_name in enumerate(lista_top10):
                    
                    df_name_map_top10 = df_mapeo_cell[df_mapeo_cell['cellosaurus_id'].isin([cell_name])]
                    
                    if not df_name_map_top10.empty:
                        cells.append(df_name_map_top10['cell_id'][0])
                        values.append(lista_val_top10[index])
                        
                lista.append([df_name_map['cell_id'][0],cells,values])

# %%
#TOP10
listas_top10_mappings =pd.DataFrame(lista, columns=['cell_id','cell_top10','value_top10'])
listas_top10_mappings.to_csv('listas_top10_mapping.csv',index=0)

# %%
lista_mapp = pd.read_csv('listas_top10_mapping.csv')
lista_mapp
# Out:
#      cell_id                                         cell_top10  \
# 0        433      [1501, 1262, 1434, 622, 1478, 651, 1220, 646]
# 1        163  [698, 651, 646, 1501, 641, 786, 165, 633, 623,...
# 2        377          [408, 1506, 646, 633, 641, 786, 651, 405]
# 3        620                                             [1611]
# 4        621                                   [478, 610, 1019]
# ..       ...                                                ...
# 224     1455    [1213, 672, 633, 405, 797, 623, 641, 646, 1228]
# 225     1533            [1577, 346, 1511, 564, 1445, 1444, 623]
# 226      690      [616, 641, 668, 469, 565, 562, 789, 786, 633]
# 227     1583  [1244, 1448, 1447, 1523, 1477, 1502, 796, 1508...
# 228     1695                                             [1570]
#
#                                            value_top10
# 0    [0.8292894588490054, 0.8187765547886937, 0.817...
# 1    [0.8956966327324026, 0.8660311334932109, 0.860...
# 2    [0.9168315626718784, 0.8976510508479817, 0.849...
# 3                                 [0.8098843080753313]
# 4    [0.8294095294386521, 0.8142067128807, 0.812799...
# ..                                                 ...
# 224  [0.9305981530637462, 0.8930398688043325, 0.852...
# 225  [0.8913037376746437, 0.8713244885021245, 0.865...
# 226  [0.9188851898350272, 0.917131990382638, 0.9129...
# 227  [0.8432030936449469, 0.8339376712523123, 0.829...
# 228                               [0.8582092968135907]
#
# [229 rows x 3 columns]

# %%
#TOP3
lista_mapp = pd.read_csv('listas_top3_mapping.csv')
lista_mapp
# Out:
#      cell_id          cell_top10  \
# 0        433        [1501, 1262]
# 1        163     [698, 651, 646]
# 2        377         [408, 1506]
# 3        620              [1611]
# 4        621    [478, 610, 1019]
# ..       ...                 ...
# 224     1455         [1213, 672]
# 225     1533         [1577, 346]
# 226      690     [616, 641, 668]
# 227     1583  [1244, 1448, 1447]
# 228     1695                  []
#
#                                            value_top10
# 0             [0.8292894588490054, 0.8187765547886937]
# 1    [0.8956966327324026, 0.8660311334932109, 0.860...
# 2             [0.9168315626718784, 0.8976510508479817]
# 3                                 [0.8098843080753313]
# 4    [0.8294095294386521, 0.8142067128807, 0.812799...
# ..                                                 ...
# 224           [0.9305981530637462, 0.8930398688043325]
# 225           [0.8913037376746437, 0.8713244885021245]
# 226  [0.9188851898350272, 0.917131990382638, 0.9129...
# 227  [0.8432030936449469, 0.8339376712523123, 0.829...
# 228                                                 []
#
# [229 rows x 3 columns]

# %%
#TOP5
lista_mapp = pd.read_csv('listas_top5_mapping.csv')
lista_mapp
# Out:
#      cell_id                      cell_top10  \
# 0        433         [1501, 1262, 1434, 622]
# 1        163      [698, 651, 646, 1501, 641]
# 2        377                [408, 1506, 646]
# 3        620                          [1611]
# 4        621                [478, 610, 1019]
# ..       ...                             ...
# 224     1455           [1213, 672, 633, 405]
# 225     1533               [1577, 346, 1511]
# 226      690            [616, 641, 668, 469]
# 227     1583  [1244, 1448, 1447, 1523, 1477]
# 228     1695                          [1570]
#
#                                            value_top10
# 0    [0.8292894588490054, 0.8187765547886937, 0.817...
# 1    [0.8956966327324026, 0.8660311334932109, 0.860...
# 2    [0.9168315626718784, 0.8976510508479817, 0.849...
# 3                                 [0.8098843080753313]
# 4    [0.8294095294386521, 0.8142067128807, 0.812799...
# ..                                                 ...
# 224  [0.9305981530637462, 0.8930398688043325, 0.852...
# 225  [0.8913037376746437, 0.8713244885021245, 0.865...
# 226  [0.9188851898350272, 0.917131990382638, 0.9129...
# 227  [0.8432030936449469, 0.8339376712523123, 0.829...
# 228                               [0.8582092968135907]
#
# [229 rows x 3 columns]
